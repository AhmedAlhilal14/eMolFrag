# %% [markdown]
# <a href="https://colab.research.google.com/github/schwallergroup/ai4chem_course/blob/main/notebooks/03%20-%20Intro%20to%20Deep%20Learning/03_gnn_simple_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 3 tutorial 2 - AI 4 Chemistry
#
# ## Table of content
#
# 0. Relevant packages
# 1. Train GNNs using chemprop

# %% [markdown]
# # 0. Relevant packages
#
# ### Chemprop
# Chemprop package contains message passing neural networks for molecular property prediction as described in the paper [Analyzing Learned Molecular Representations for Property Prediction](https://pubs.acs.org/doi/abs/10.1021/acs.jcim.9b00237) and as used in the paper [A Deep Learning Approach to Antibiotic Discovery](https://www.cell.com/cell/fulltext/S0092-8674(20)30102-1) for molecules and [Machine Learning of Reaction Properties via Learned Representations of the Condensed Graph of Reaction](https://doi.org/10.1021/acs.jcim.1c00975) for reactions.
#
# **Documentation:** Full documentation of Chemprop is available at https://chemprop.readthedocs.io/en/latest/.
#
# **Website:** A web prediction interface with some trained Chemprop models is available at [chemprop.csail.mit.edu](http://chemprop.csail.mit.edu).
#
# **Tutorial:** These [slides](https://docs.google.com/presentation/d/14pbd9LTXzfPSJHyXYkfLxnK8Q80LhVnjImg8a3WqCRM/edit?usp=sharing) provide a Chemprop tutorial and highlight recent additions as of April 28th, 2020.

# %%
# Install chemprop
# CoLab has already preinstalled Pytorch for you
! pip install chemprop rdkit

# Download ESOL data
! mkdir data/
! wget https://raw.githubusercontent.com/schwallergroup/ai4chem_course/main/notebooks/02%20-%20Supervised%20Learning/data/esol.csv -O data/esol.csv
# Out:
# Collecting chemprop
#   Downloading chemprop-1.6.1-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 2.6 MB/s eta 0:00:00
# Collecting rdkit
#   Downloading rdkit-2024.3.6-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: flask>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from chemprop) (3.0.3)
# Requirement already satisfied: hyperopt>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from chemprop) (0.2.7)
# Requirement already satisfied: matplotlib>=3.1.3 in /usr/local/lib/python3.10/dist-packages (from chemprop) (3.8.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.10/dist-packages (from chemprop) (1.26.4)
# Requirement already satisfied: pandas>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from chemprop) (2.2.2)
# Collecting pandas-flavor>=0.2.0 (from chemprop)
#   Downloading pandas_flavor-0.6.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from chemprop) (1.5.2)
# Requirement already satisfied: sphinx>=3.1.2 in /usr/local/lib/python3.10/dist-packages (from chemprop) (8.1.3)
# Collecting tensorboardX>=2.0 (from chemprop)
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from chemprop) (2.5.1+cu121)
# Requirement already satisfied: tqdm>=4.45.0 in /usr/local/lib/python3.10/dist-packages (from chemprop) (4.66.6)
# Collecting typed-argument-parser>=1.6.1 (from chemprop)
#   Downloading typed_argument_parser-1.10.1-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (11.0.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from flask>=1.1.2->chemprop) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.10/dist-packages (from flask>=1.1.2->chemprop) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from flask>=1.1.2->chemprop) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from flask>=1.1.2->chemprop) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.10/dist-packages (from flask>=1.1.2->chemprop) (1.9.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.3->chemprop) (1.13.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.3->chemprop) (1.16.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.3->chemprop) (3.4.2)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.3->chemprop) (1.0.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.3->chemprop) (3.1.0)
# Requirement already satisfied: py4j in /usr/local/lib/python3.10/dist-packages (from hyperopt>=0.2.3->chemprop) (0.10.9.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->chemprop) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->chemprop) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->chemprop) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->chemprop) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->chemprop) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->chemprop) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.1.3->chemprop) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.3->chemprop) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.3->chemprop) (2024.2)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from pandas-flavor>=0.2.0->chemprop) (2024.10.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->chemprop) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->chemprop) (3.5.0)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from sphinx>=3.1.2->chemprop) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.10/dist-packages (from sphinx>=3.1.2->chemprop) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from sphinx>=3.1.2->chemprop) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from sphinx>=3.1.2->chemprop) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.10/dist-packages (from sphinx>=3.1.2->chemprop) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.10/dist-packages (from sphinx>=3.1.2->chemprop) (2.0.0)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.10/dist-packages (from sphinx>=3.1.2->chemprop) (2.18.0)
# Requirement already satisfied: docutils<0.22,>=0.20 in /usr/local/lib/python3.10/dist-packages (from sphinx>=3.1.2->chemprop) (0.21.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.10/dist-packages (from sphinx>=3.1.2->chemprop) (2.2.0)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.10/dist-packages (from sphinx>=3.1.2->chemprop) (2.16.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.10/dist-packages (from sphinx>=3.1.2->chemprop) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.10/dist-packages (from sphinx>=3.1.2->chemprop) (1.4.1)
# Requirement already satisfied: requests>=2.30.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=3.1.2->chemprop) (2.32.3)
# Requirement already satisfied: tomli>=2 in /usr/local/lib/python3.10/dist-packages (from sphinx>=3.1.2->chemprop) (2.1.0)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorboardX>=2.0->chemprop) (4.25.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->chemprop) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->chemprop) (4.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->chemprop) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->chemprop) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.4.0->chemprop) (1.3.0)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.10/dist-packages (from typed-argument-parser>=1.6.1->chemprop) (0.16)
# Collecting typing-inspect>=0.7.1 (from typed-argument-parser>=1.6.1->chemprop)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.1.2->flask>=1.1.2->chemprop) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.30.0->sphinx>=3.1.2->chemprop) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.30.0->sphinx>=3.1.2->chemprop) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.30.0->sphinx>=3.1.2->chemprop) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.30.0->sphinx>=3.1.2->chemprop) (2024.8.30)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.7.1->typed-argument-parser>=1.6.1->chemprop)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading chemprop-1.6.1-py3-none-any.whl (166 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.4/166.4 kB 11.9 MB/s eta 0:00:00
# Downloading rdkit-2024.3.6-cp310-cp310-manylinux_2_28_x86_64.whl (32.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 24.1 MB/s eta 0:00:00
# Downloading pandas_flavor-0.6.0-py3-none-any.whl (7.2 kB)
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 7.5 MB/s eta 0:00:00
# Downloading typed_argument_parser-1.10.1-py3-none-any.whl (30 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: tensorboardX, rdkit, mypy-extensions, typing-inspect, typed-argument-parser, pandas-flavor, chemprop
# Successfully installed chemprop-1.6.1 mypy-extensions-1.0.0 pandas-flavor-0.6.0 rdkit-2024.3.6 tensorboardX-2.6.2.2 typed-argument-parser-1.10.1 typing-inspect-0.9.0
# --2024-12-02 22:54:06--  https://raw.githubusercontent.com/schwallergroup/ai4chem_course/main/notebooks/02%20-%20Supervised%20Learning/data/esol.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34453 (34K) [text/plain]
# Saving to: ‘data/esol.csv’
#
# data/esol.csv       100%[===================>]  33.65K  --.-KB/s    in 0.01s
#
# 2024-12-02 22:54:06 (2.86 MB/s) - ‘data/esol.csv’ saved [34453/34453]

# %% [markdown]
# Set a random seed to ensure repeatability of experiments

# %%
import random
import numpy as np
import torch

# Random Seeds and Reproducibility
torch.manual_seed(0)
torch.cuda.manual_seed(0)
np.random.seed(0)
random.seed(0)

# %% [markdown]
# # 1. Train GNNs using chemprop
#
# To train a GNN model, run:
# ```
# chemprop_train --data_path <path> --dataset_type <type> --save_dir <dir>
# ```
# where `<path>` is the path to a CSV file containing a dataset, `<type>` is one of [classification, regression, multiclass, spectra] depending on the type of the dataset, and `<dir>` is the directory where train results and model checkpoints will be saved. For more details for CSV data style, please see [here](https://github.com/chemprop/chemprop#data).
#
# For example:
# ```
# chemprop_train --data_path data/tox21.csv --dataset_type classification --save_dir tox21_checkpoints
# ```
#
# A full list of available command-line arguments can be found in [chemprop/args.py](https://github.com/chemprop/chemprop/blob/master/chemprop/args.py).
#
# For model evaluation metrics, please see in [README.md](https://github.com/chemprop/chemprop#metrics).

# %%
! chemprop_train --data_path data/esol.csv \
                 --dataset_type regression \
                 --save_dir esol_ckpts \
                 --metric rmse \
                 --split_sizes 0.7 0.1 0.2 \
                 --epochs 60
# Out:
# Command line
# python /usr/local/bin/chemprop_train --data_path data/esol.csv --dataset_type regression --save_dir esol_ckpts --metric rmse --split_sizes 0.7 0.1 0.2 --epochs 60
# Args
# {'activation': 'ReLU',
#  'adding_bond_types': True,
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_constraints': [],
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'atom_targets': [],
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_constraints': [],
#  'bond_descriptor_scaling': True,
#  'bond_descriptors': None,
#  'bond_descriptors_path': None,
#  'bond_descriptors_size': 0,
#  'bond_features_size': 0,
#  'bond_targets': [],
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'constraints_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': False,
#  'data_path': 'data/esol.csv',
#  'data_weights_path': None,
#  'dataset_type': 'regression',
#  'depth': 3,
#  'depth_solvent': 3,
#  'device': device(type='cpu'),
#  'dropout': 0.0,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 60,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': None,
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': True,
#  'features_size': None,
#  'ffn_hidden_size': 300,
#  'ffn_num_layers': 2,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': None,
#  'grad_clip': None,
#  'hidden_size': 300,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'is_atom_bond_targets': False,
#  'keeping_atom_map': False,
#  'log_frequency': 10,
#  'loss_function': 'mse',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'rmse',
#  'metrics': ['rmse'],
#  'minimize_score': True,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_adding_bond_types': False,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_descriptor_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': False,
#  'no_shared_atom_bond_ffn': False,
#  'num_folds': 1,
#  'num_lrs': 1,
#  'num_tasks': 1,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': 'esol_ckpts',
#  'save_preds': False,
#  'save_smiles_splits': False,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_descriptors_path': None,
#  'separate_test_constraints_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': None,
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_descriptors_path': None,
#  'separate_val_constraints_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': None,
#  'separate_val_phase_features_path': None,
#  'shared_atom_bond_ffn': True,
#  'show_individual_scores': False,
#  'smiles_columns': ['smiles'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [0.7, 0.1, 0.2],
#  'split_type': 'random',
#  'target_columns': None,
#  'target_weights': None,
#  'task_names': ['log solubility (mol/L)'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': False,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0,
#  'weights_ffn_num_layers': 2}
# Setting molecule featurization parameters to default.
# Loading data
# 1128it [00:00, 199400.47it/s]
# 100% 1128/1128 [00:00<00:00, 128268.26it/s]
# 100% 1128/1128 [00:00<00:00, 5045.67it/s]
# Number of tasks = 1
# Fold 0
# Splitting data with seed 0
# Total size = 1,128 | train size = 789 | val size = 113 | test size = 226
# Fitting scaler
# Building model 0
# MoleculeModel(
#   (encoder): MPN(
#     (encoder): ModuleList(
#       (0): MPNEncoder(
#         (dropout): Dropout(p=0.0, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=147, out_features=300, bias=False)
#         (W_h): Linear(in_features=300, out_features=300, bias=False)
#         (W_o): Linear(in_features=433, out_features=300, bias=True)
#       )
#     )
#   )
#   (readout): Sequential(
#     (0): Dropout(p=0.0, inplace=False)
#     (1): Linear(in_features=300, out_features=300, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.0, inplace=False)
#     (4): Linear(in_features=300, out_features=1, bias=True)
#   )
# )
# Number of parameters = 355,201
#   0% 0/60 [00:00<?, ?it/s]Epoch 0
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:06,  2.17it/s]
#  12% 2/16 [00:00<00:04,  3.23it/s]
#  19% 3/16 [00:00<00:03,  3.49it/s]
#  25% 4/16 [00:01<00:03,  3.71it/s]
#  31% 5/16 [00:01<00:02,  3.86it/s]
#  38% 6/16 [00:01<00:02,  4.18it/s]
#  44% 7/16 [00:01<00:02,  4.14it/s]
#  50% 8/16 [00:02<00:01,  4.36it/s]
#  56% 9/16 [00:02<00:01,  4.04it/s]Loss = 9.3085e-01, PNorm = 34.0175, GNorm = 2.1311, lr_0 = 4.3000e-04
#
#  62% 10/16 [00:02<00:01,  4.15it/s]
#  69% 11/16 [00:02<00:01,  4.07it/s]
#  75% 12/16 [00:02<00:00,  4.75it/s]
#  81% 13/16 [00:03<00:00,  5.33it/s]
#  88% 14/16 [00:03<00:00,  5.63it/s]
#  94% 15/16 [00:03<00:00,  6.04it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 10.61it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 1.735671
#   2% 1/60 [00:03<03:55,  4.00s/it]Epoch 1
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:01,  8.07it/s]
#  19% 3/16 [00:00<00:01,  9.44it/s]
#  25% 4/16 [00:00<00:01,  9.06it/s]Loss = 7.2703e-01, PNorm = 34.0468, GNorm = 3.9153, lr_0 = 7.6000e-04
#
#  38% 6/16 [00:00<00:01,  9.19it/s]
#  50% 8/16 [00:00<00:00,  9.43it/s]
#  56% 9/16 [00:00<00:00,  9.43it/s]
#  62% 10/16 [00:01<00:00,  9.36it/s]
#  69% 11/16 [00:01<00:00,  9.04it/s]
#  81% 13/16 [00:01<00:00,  9.37it/s]
#  88% 14/16 [00:01<00:00,  8.91it/s]Loss = 6.0840e-01, PNorm = 34.0869, GNorm = 2.7628, lr_0 = 9.9472e-04
#
#  94% 15/16 [00:01<00:00,  9.03it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 15.70it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 1.466846
#   3% 2/60 [00:05<02:42,  2.80s/it]Epoch 2
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:01,  9.13it/s]
#  12% 2/16 [00:00<00:01,  9.11it/s]
#  19% 3/16 [00:00<00:01,  9.35it/s]
#  25% 4/16 [00:00<00:01,  9.38it/s]
#  31% 5/16 [00:00<00:01,  8.55it/s]
#  38% 6/16 [00:00<00:01,  7.13it/s]
#  44% 7/16 [00:00<00:01,  7.16it/s]
#  50% 8/16 [00:01<00:01,  6.58it/s]Loss = 4.8764e-01, PNorm = 34.1416, GNorm = 7.7092, lr_0 = 9.6874e-04
#
#  56% 9/16 [00:01<00:01,  6.26it/s]
#  62% 10/16 [00:01<00:00,  6.13it/s]
#  69% 11/16 [00:01<00:00,  6.45it/s]
#  75% 12/16 [00:01<00:00,  7.14it/s]
#  81% 13/16 [00:01<00:00,  7.28it/s]
#  88% 14/16 [00:01<00:00,  7.79it/s]
# 100% 16/16 [00:02<00:00,  9.03it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 15.32it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 1.254512
#   5% 3/60 [00:08<02:26,  2.57s/it]Epoch 3
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:01,  9.28it/s]
#  12% 2/16 [00:00<00:01,  8.97it/s]Loss = 2.9940e-01, PNorm = 34.1947, GNorm = 2.0048, lr_0 = 9.4344e-04
#
#  19% 3/16 [00:00<00:01,  8.82it/s]
#  25% 4/16 [00:00<00:01,  9.15it/s]
#  31% 5/16 [00:00<00:01,  9.32it/s]
#  38% 6/16 [00:00<00:01,  8.96it/s]
#  44% 7/16 [00:00<00:00,  9.18it/s]
#  50% 8/16 [00:00<00:00,  9.04it/s]
#  56% 9/16 [00:00<00:00,  9.23it/s]
#  69% 11/16 [00:01<00:00,  9.69it/s]
#  75% 12/16 [00:01<00:00,  8.97it/s]Loss = 2.9555e-01, PNorm = 34.2437, GNorm = 2.4857, lr_0 = 9.1879e-04
#
#  81% 13/16 [00:01<00:00,  8.83it/s]
#  88% 14/16 [00:01<00:00,  9.07it/s]
# 100% 16/16 [00:01<00:00, 10.26it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 15.84it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 1.141236
#   7% 4/60 [00:10<02:09,  2.31s/it]Epoch 4
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:01,  8.32it/s]
#  12% 2/16 [00:00<00:01,  8.62it/s]
#  19% 3/16 [00:00<00:01,  8.53it/s]
#  25% 4/16 [00:00<00:01,  8.34it/s]
#  38% 6/16 [00:00<00:01,  9.03it/s]Loss = 2.7940e-01, PNorm = 34.2854, GNorm = 2.7490, lr_0 = 8.9480e-04
#
#  44% 7/16 [00:00<00:00,  9.25it/s]
#  50% 8/16 [00:00<00:00,  9.15it/s]
#  56% 9/16 [00:01<00:00,  9.13it/s]
#  62% 10/16 [00:01<00:00,  9.27it/s]
#  75% 12/16 [00:01<00:00,  9.82it/s]
#  81% 13/16 [00:01<00:00,  9.55it/s]
#  88% 14/16 [00:01<00:00,  9.47it/s]
#  94% 15/16 [00:01<00:00,  9.53it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 16.71it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 1.091753
#   8% 5/60 [00:12<01:59,  2.17s/it]Epoch 5
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:01,  9.67it/s]Loss = 1.7047e-01, PNorm = 34.3269, GNorm = 1.3530, lr_0 = 8.6912e-04
#
#  12% 2/16 [00:00<00:01,  9.17it/s]
#  19% 3/16 [00:00<00:01,  9.43it/s]
#  25% 4/16 [00:00<00:01,  8.85it/s]
#  31% 5/16 [00:00<00:01,  8.61it/s]
#  44% 7/16 [00:00<00:00,  9.16it/s]
#  50% 8/16 [00:00<00:00,  8.30it/s]
#  56% 9/16 [00:01<00:00,  7.46it/s]
#  62% 10/16 [00:01<00:00,  6.67it/s]
#  69% 11/16 [00:01<00:00,  6.47it/s]Loss = 2.3532e-01, PNorm = 34.3715, GNorm = 5.4369, lr_0 = 8.4642e-04
#
#  75% 12/16 [00:01<00:00,  6.37it/s]
#  81% 13/16 [00:01<00:00,  6.60it/s]
#  88% 14/16 [00:01<00:00,  6.02it/s]
#  94% 15/16 [00:02<00:00,  6.18it/s]
# 100% 16/16 [00:02<00:00,  6.21it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  33% 1/3 [00:00<00:00,  9.53it/s]
#  67% 2/3 [00:00<00:00,  9.06it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.948797
#  10% 6/60 [00:14<02:05,  2.32s/it]Epoch 6
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:02,  5.96it/s]
#  12% 2/16 [00:00<00:02,  6.23it/s]
#  19% 3/16 [00:00<00:02,  5.50it/s]
#  25% 4/16 [00:00<00:02,  5.45it/s]
#  31% 5/16 [00:00<00:01,  5.69it/s]Loss = 1.6294e-01, PNorm = 34.4152, GNorm = 1.2708, lr_0 = 8.2431e-04
#
#  38% 6/16 [00:01<00:01,  5.49it/s]
#  44% 7/16 [00:01<00:01,  5.33it/s]
#  50% 8/16 [00:01<00:01,  5.50it/s]
#  56% 9/16 [00:01<00:01,  5.62it/s]
#  62% 10/16 [00:01<00:01,  5.79it/s]
#  69% 11/16 [00:01<00:00,  5.84it/s]
#  75% 12/16 [00:02<00:00,  5.89it/s]
#  81% 13/16 [00:02<00:00,  6.05it/s]
#  88% 14/16 [00:02<00:00,  5.93it/s]
#  94% 15/16 [00:02<00:00,  6.35it/s]Loss = 1.6158e-01, PNorm = 34.4494, GNorm = 6.9347, lr_0 = 8.0278e-04
#
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 15.07it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.884657
#  12% 7/60 [00:17<02:12,  2.50s/it]Epoch 7
#
#   0% 0/16 [00:00<?, ?it/s]
#  12% 2/16 [00:00<00:01,  9.23it/s]
#  19% 3/16 [00:00<00:01,  9.36it/s]
#  25% 4/16 [00:00<00:01,  8.70it/s]
#  31% 5/16 [00:00<00:01,  8.41it/s]
#  38% 6/16 [00:00<00:01,  8.86it/s]
#  50% 8/16 [00:00<00:00,  9.52it/s]
#  56% 9/16 [00:00<00:00,  9.11it/s]Loss = 1.6128e-01, PNorm = 34.4857, GNorm = 0.9429, lr_0 = 7.8181e-04
#
#  62% 10/16 [00:01<00:00,  9.23it/s]
#  69% 11/16 [00:01<00:00,  9.42it/s]
#  75% 12/16 [00:01<00:00,  9.43it/s]
#  81% 13/16 [00:01<00:00,  9.43it/s]
#  88% 14/16 [00:01<00:00,  9.16it/s]
#  94% 15/16 [00:01<00:00,  9.35it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 15.42it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.863129
#  13% 8/60 [00:19<02:00,  2.32s/it]Epoch 8
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:01,  8.79it/s]
#  12% 2/16 [00:00<00:01,  9.14it/s]Loss = 1.4262e-01, PNorm = 34.5163, GNorm = 2.6213, lr_0 = 7.6139e-04
#
#  25% 4/16 [00:00<00:01,  9.43it/s]
#  31% 5/16 [00:00<00:01,  9.30it/s]
#  38% 6/16 [00:00<00:01,  9.45it/s]
#  44% 7/16 [00:00<00:00,  9.61it/s]
#  56% 9/16 [00:00<00:00,  9.56it/s]
#  69% 11/16 [00:01<00:00,  9.68it/s]
#  75% 12/16 [00:01<00:00,  9.60it/s]
#  81% 13/16 [00:01<00:00,  9.46it/s]Loss = 1.8558e-01, PNorm = 34.5406, GNorm = 3.3376, lr_0 = 7.4151e-04
#
#  88% 14/16 [00:01<00:00,  8.91it/s]
#  94% 15/16 [00:01<00:00,  8.94it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 15.61it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.880173
#  15% 9/60 [00:21<01:50,  2.17s/it]Epoch 9
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:01,  8.32it/s]
#  12% 2/16 [00:00<00:01,  8.56it/s]
#  19% 3/16 [00:00<00:01,  8.99it/s]
#  31% 5/16 [00:00<00:01,  9.42it/s]
#  38% 6/16 [00:00<00:01,  9.38it/s]
#  44% 7/16 [00:00<00:01,  8.91it/s]Loss = 1.3601e-01, PNorm = 34.5735, GNorm = 1.1956, lr_0 = 7.2214e-04
#
#  50% 8/16 [00:00<00:00,  9.05it/s]
#  56% 9/16 [00:00<00:00,  9.18it/s]
#  62% 10/16 [00:01<00:00,  9.19it/s]
#  69% 11/16 [00:01<00:00,  9.30it/s]
#  81% 13/16 [00:01<00:00,  9.65it/s]
#  94% 15/16 [00:01<00:00,  9.48it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 15.25it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.795464
#  17% 10/60 [00:23<01:44,  2.09s/it]Epoch 10
#
#   0% 0/16 [00:00<?, ?it/s]
#  12% 2/16 [00:00<00:01, 10.20it/s]Loss = 1.1600e-01, PNorm = 34.6071, GNorm = 3.2392, lr_0 = 7.0142e-04
#
#  25% 4/16 [00:00<00:01,  9.03it/s]
#  38% 6/16 [00:00<00:01,  9.18it/s]
#  44% 7/16 [00:00<00:00,  9.24it/s]
#  50% 8/16 [00:00<00:00,  8.79it/s]
#  56% 9/16 [00:00<00:00,  8.88it/s]
#  62% 10/16 [00:01<00:00,  9.09it/s]
#  69% 11/16 [00:01<00:00,  8.91it/s]
#  75% 12/16 [00:01<00:00,  8.89it/s]Loss = 1.1477e-01, PNorm = 34.6340, GNorm = 0.7571, lr_0 = 6.8310e-04
#
#  81% 13/16 [00:01<00:00,  8.90it/s]
#  88% 14/16 [00:01<00:00,  9.17it/s]
# 100% 16/16 [00:01<00:00, 10.04it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 15.24it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.761541
#  18% 11/60 [00:25<01:40,  2.05s/it]Epoch 11
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:01,  8.90it/s]
#  19% 3/16 [00:00<00:01,  9.32it/s]
#  31% 5/16 [00:00<00:01,  9.96it/s]
#  38% 6/16 [00:00<00:01,  9.82it/s]Loss = 9.8539e-02, PNorm = 34.6616, GNorm = 2.4287, lr_0 = 6.6526e-04
#
#  44% 7/16 [00:00<00:00,  9.67it/s]
#  50% 8/16 [00:00<00:00,  9.69it/s]
#  56% 9/16 [00:00<00:00,  8.59it/s]
#  62% 10/16 [00:01<00:00,  8.47it/s]
#  69% 11/16 [00:01<00:00,  8.84it/s]
#  81% 13/16 [00:01<00:00,  9.12it/s]
#  88% 14/16 [00:01<00:00,  9.28it/s]
#  94% 15/16 [00:01<00:00,  9.22it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 16.17it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.777377
#  20% 12/60 [00:27<01:35,  1.99s/it]Epoch 12
#
#   0% 0/16 [00:00<?, ?it/s]Loss = 9.7542e-02, PNorm = 34.6828, GNorm = 1.6409, lr_0 = 6.4788e-04
#
#   6% 1/16 [00:00<00:01,  9.11it/s]
#  12% 2/16 [00:00<00:02,  6.42it/s]
#  19% 3/16 [00:00<00:02,  6.22it/s]
#  25% 4/16 [00:00<00:02,  5.99it/s]
#  31% 5/16 [00:00<00:01,  5.98it/s]
#  38% 6/16 [00:00<00:01,  5.85it/s]
#  44% 7/16 [00:01<00:01,  5.89it/s]
#  50% 8/16 [00:01<00:01,  5.90it/s]
#  56% 9/16 [00:01<00:01,  5.76it/s]
#  62% 10/16 [00:01<00:01,  5.77it/s]Loss = 1.1232e-01, PNorm = 34.7090, GNorm = 5.6879, lr_0 = 6.3096e-04
#
#  69% 11/16 [00:01<00:00,  5.79it/s]
#  75% 12/16 [00:02<00:00,  5.98it/s]
#  81% 13/16 [00:02<00:00,  5.80it/s]
#  88% 14/16 [00:02<00:00,  5.81it/s]
#  94% 15/16 [00:02<00:00,  5.65it/s]
# 100% 16/16 [00:02<00:00,  6.14it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00,  9.79it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.884014
#  22% 13/60 [00:29<01:46,  2.27s/it]Epoch 13
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:02,  5.13it/s]
#  12% 2/16 [00:00<00:02,  5.51it/s]
#  19% 3/16 [00:00<00:02,  5.34it/s]
#  25% 4/16 [00:00<00:02,  5.51it/s]Loss = 1.2280e-01, PNorm = 34.7306, GNorm = 1.5890, lr_0 = 6.1448e-04
#
#  31% 5/16 [00:00<00:01,  5.65it/s]
#  38% 6/16 [00:01<00:01,  5.92it/s]
#  44% 7/16 [00:01<00:01,  5.60it/s]
#  50% 8/16 [00:01<00:01,  5.74it/s]
#  56% 9/16 [00:01<00:01,  5.93it/s]
#  62% 10/16 [00:01<00:00,  6.76it/s]
#  75% 12/16 [00:01<00:00,  7.70it/s]
#  81% 13/16 [00:02<00:00,  7.69it/s]
#  88% 14/16 [00:02<00:00,  8.17it/s]Loss = 1.0021e-01, PNorm = 34.7559, GNorm = 2.9559, lr_0 = 5.9843e-04
#
#  94% 15/16 [00:02<00:00,  8.02it/s]Loss = 6.5466e-02, PNorm = 34.7586, GNorm = 2.3582, lr_0 = 5.9685e-04
#
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 16.53it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.944293
#  23% 14/60 [00:32<01:47,  2.34s/it]Epoch 14
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:02,  6.40it/s]
#  12% 2/16 [00:00<00:01,  8.11it/s]
#  19% 3/16 [00:00<00:01,  8.67it/s]
#  25% 4/16 [00:00<00:01,  9.14it/s]
#  31% 5/16 [00:00<00:01,  8.80it/s]
#  38% 6/16 [00:00<00:01,  9.06it/s]
#  44% 7/16 [00:00<00:00,  9.18it/s]
#  50% 8/16 [00:00<00:00,  9.19it/s]
#  56% 9/16 [00:01<00:00,  9.27it/s]Loss = 9.4756e-02, PNorm = 34.7841, GNorm = 3.3433, lr_0 = 5.8126e-04
#
#  62% 10/16 [00:01<00:00,  8.93it/s]
#  75% 12/16 [00:01<00:00,  9.50it/s]
#  88% 14/16 [00:01<00:00,  9.35it/s]
#  94% 15/16 [00:01<00:00,  9.21it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 15.23it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.801449
#  25% 15/60 [00:34<01:39,  2.20s/it]Epoch 15
#
#   0% 0/16 [00:00<?, ?it/s]
#  12% 2/16 [00:00<00:01,  8.89it/s]
#  19% 3/16 [00:00<00:01,  8.42it/s]Loss = 8.4183e-02, PNorm = 34.8043, GNorm = 0.7363, lr_0 = 5.6607e-04
#
#  25% 4/16 [00:00<00:01,  8.79it/s]
#  38% 6/16 [00:00<00:01,  9.31it/s]
#  44% 7/16 [00:00<00:00,  9.28it/s]
#  50% 8/16 [00:00<00:00,  9.10it/s]
#  56% 9/16 [00:00<00:00,  9.08it/s]
#  69% 11/16 [00:01<00:00,  9.75it/s]
#  75% 12/16 [00:01<00:00,  9.24it/s]
#  81% 13/16 [00:01<00:00,  9.32it/s]Loss = 1.0500e-01, PNorm = 34.8261, GNorm = 1.6395, lr_0 = 5.5129e-04
#
#  88% 14/16 [00:01<00:00,  9.28it/s]
#  94% 15/16 [00:01<00:00,  8.89it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 14.86it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.701954
#  27% 16/60 [00:36<01:33,  2.13s/it]Epoch 16
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:01,  7.96it/s]
#  12% 2/16 [00:00<00:01,  8.59it/s]
#  19% 3/16 [00:00<00:01,  8.13it/s]
#  31% 5/16 [00:00<00:01,  9.18it/s]
#  38% 6/16 [00:00<00:01,  9.21it/s]
#  44% 7/16 [00:00<00:01,  8.96it/s]Loss = 8.8858e-02, PNorm = 34.8494, GNorm = 1.1469, lr_0 = 5.3689e-04
#
#  50% 8/16 [00:00<00:00,  8.44it/s]
#  56% 9/16 [00:01<00:00,  8.66it/s]
#  62% 10/16 [00:01<00:00,  8.40it/s]
#  75% 12/16 [00:01<00:00,  8.68it/s]
#  81% 13/16 [00:01<00:00,  8.77it/s]
#  88% 14/16 [00:01<00:00,  8.83it/s]
#  94% 15/16 [00:01<00:00,  8.42it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 15.75it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.683580
#  28% 17/60 [00:38<01:30,  2.10s/it]Epoch 17
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:01,  9.20it/s]Loss = 7.9422e-02, PNorm = 34.8709, GNorm = 1.1141, lr_0 = 5.2287e-04
#
#  19% 3/16 [00:00<00:01,  9.68it/s]
#  25% 4/16 [00:00<00:01,  8.93it/s]
#  31% 5/16 [00:00<00:01,  8.70it/s]
#  38% 6/16 [00:00<00:01,  8.89it/s]
#  44% 7/16 [00:00<00:00,  9.03it/s]
#  50% 8/16 [00:00<00:00,  8.91it/s]
#  56% 9/16 [00:01<00:00,  8.83it/s]
#  69% 11/16 [00:01<00:00,  9.23it/s]Loss = 6.9442e-02, PNorm = 34.8894, GNorm = 0.4835, lr_0 = 5.0921e-04
#
#  75% 12/16 [00:01<00:00,  9.22it/s]
#  81% 13/16 [00:01<00:00,  8.94it/s]
#  88% 14/16 [00:01<00:00,  8.87it/s]
#  94% 15/16 [00:01<00:00,  8.92it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 16.23it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.792675
#  30% 18/60 [00:40<01:25,  2.04s/it]Epoch 18
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:01,  9.23it/s]
#  12% 2/16 [00:00<00:01,  9.27it/s]
#  25% 4/16 [00:00<00:01,  9.79it/s]
#  31% 5/16 [00:00<00:01,  9.45it/s]Loss = 8.3694e-02, PNorm = 34.9076, GNorm = 0.6038, lr_0 = 4.9591e-04
#
#  38% 6/16 [00:00<00:01,  8.92it/s]
#  44% 7/16 [00:00<00:01,  8.87it/s]
#  50% 8/16 [00:00<00:00,  8.79it/s]
#  56% 9/16 [00:00<00:00,  8.94it/s]
#  62% 10/16 [00:01<00:00,  8.72it/s]
#  69% 11/16 [00:01<00:00,  8.52it/s]
#  75% 12/16 [00:01<00:00,  7.62it/s]
#  81% 13/16 [00:01<00:00,  6.97it/s]
#  88% 14/16 [00:01<00:00,  6.49it/s]
#  94% 15/16 [00:01<00:00,  6.08it/s]
# 100% 16/16 [00:02<00:00,  6.40it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  33% 1/3 [00:00<00:00,  8.90it/s]
#  67% 2/3 [00:00<00:00,  8.54it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.675599
#  32% 19/60 [00:42<01:28,  2.17s/it]Epoch 19
#
#   0% 0/16 [00:00<?, ?it/s]Loss = 3.5508e-02, PNorm = 34.9271, GNorm = 1.4628, lr_0 = 4.8168e-04
#
#   6% 1/16 [00:00<00:02,  6.60it/s]
#  12% 2/16 [00:00<00:02,  5.75it/s]
#  19% 3/16 [00:00<00:02,  5.12it/s]
#  25% 4/16 [00:00<00:02,  5.59it/s]
#  31% 5/16 [00:00<00:01,  5.69it/s]
#  38% 6/16 [00:01<00:01,  5.61it/s]
#  44% 7/16 [00:01<00:01,  5.80it/s]
#  50% 8/16 [00:01<00:01,  5.61it/s]
#  56% 9/16 [00:01<00:01,  5.60it/s]
#  62% 10/16 [00:01<00:01,  5.73it/s]Loss = 6.8431e-02, PNorm = 34.9466, GNorm = 2.5540, lr_0 = 4.6910e-04
#
#  69% 11/16 [00:01<00:00,  5.74it/s]
#  75% 12/16 [00:02<00:00,  5.96it/s]
#  81% 13/16 [00:02<00:00,  5.72it/s]
#  88% 14/16 [00:02<00:00,  5.62it/s]
#  94% 15/16 [00:02<00:00,  5.85it/s]
# 100% 16/16 [00:02<00:00,  6.36it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  33% 1/3 [00:00<00:00,  9.67it/s]
#  67% 2/3 [00:00<00:00,  9.17it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.708385
#  33% 20/60 [00:45<01:36,  2.42s/it]Epoch 20
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:01,  9.50it/s]
#  12% 2/16 [00:00<00:01,  9.53it/s]
#  19% 3/16 [00:00<00:01,  9.30it/s]
#  25% 4/16 [00:00<00:01,  8.60it/s]Loss = 6.6108e-02, PNorm = 34.9612, GNorm = 1.3616, lr_0 = 4.5685e-04
#
#  31% 5/16 [00:00<00:01,  8.94it/s]
#  38% 6/16 [00:00<00:01,  9.11it/s]
#  50% 8/16 [00:00<00:00,  9.09it/s]
#  56% 9/16 [00:00<00:00,  8.90it/s]
#  62% 10/16 [00:01<00:00,  9.04it/s]
#  75% 12/16 [00:01<00:00,  9.31it/s]
#  81% 13/16 [00:01<00:00,  8.99it/s]
#  88% 14/16 [00:01<00:00,  9.11it/s]Loss = 7.5626e-02, PNorm = 34.9807, GNorm = 1.0898, lr_0 = 4.4491e-04
#
#  94% 15/16 [00:01<00:00,  8.90it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 16.17it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.700222
#  35% 21/60 [00:47<01:28,  2.26s/it]Epoch 21
#
#   0% 0/16 [00:00<?, ?it/s]
#  12% 2/16 [00:00<00:01, 10.54it/s]
#  25% 4/16 [00:00<00:01,  9.57it/s]
#  31% 5/16 [00:00<00:01,  9.41it/s]
#  38% 6/16 [00:00<00:01,  8.96it/s]
#  44% 7/16 [00:00<00:01,  8.85it/s]
#  50% 8/16 [00:00<00:00,  8.57it/s]Loss = 7.2121e-02, PNorm = 35.0008, GNorm = 2.6127, lr_0 = 4.3329e-04
#
#  56% 9/16 [00:00<00:00,  8.81it/s]
#  62% 10/16 [00:01<00:00,  9.05it/s]
#  69% 11/16 [00:01<00:00,  9.06it/s]
#  75% 12/16 [00:01<00:00,  8.78it/s]
#  88% 14/16 [00:01<00:00,  9.32it/s]
# 100% 16/16 [00:01<00:00,  9.82it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 15.76it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.660137
#  37% 22/60 [00:49<01:22,  2.16s/it]Epoch 22
#
#   0% 0/16 [00:00<?, ?it/s]
#  12% 2/16 [00:00<00:01,  9.29it/s]Loss = 5.6641e-02, PNorm = 35.0173, GNorm = 0.7147, lr_0 = 4.2198e-04
#
#  19% 3/16 [00:00<00:01,  9.11it/s]
#  25% 4/16 [00:00<00:01,  9.31it/s]
#  31% 5/16 [00:00<00:01,  9.10it/s]
#  38% 6/16 [00:00<00:01,  9.35it/s]
#  44% 7/16 [00:00<00:01,  8.93it/s]
#  50% 8/16 [00:00<00:00,  9.02it/s]
#  56% 9/16 [00:00<00:00,  9.23it/s]
#  62% 10/16 [00:01<00:00,  9.31it/s]
#  69% 11/16 [00:01<00:00,  9.37it/s]Loss = 5.6961e-02, PNorm = 35.0341, GNorm = 1.8855, lr_0 = 4.1095e-04
#
#  81% 13/16 [00:01<00:00,  9.32it/s]
#  88% 14/16 [00:01<00:00,  9.12it/s]
#  94% 15/16 [00:01<00:00,  8.84it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 14.52it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.661858
#  38% 23/60 [00:51<01:17,  2.08s/it]Epoch 23
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:01,  9.88it/s]
#  12% 2/16 [00:00<00:01,  9.67it/s]
#  19% 3/16 [00:00<00:01,  8.84it/s]
#  25% 4/16 [00:00<00:01,  8.93it/s]
#  38% 6/16 [00:00<00:01,  9.37it/s]
#  44% 7/16 [00:00<00:00,  9.43it/s]Loss = 5.8572e-02, PNorm = 35.0512, GNorm = 1.4584, lr_0 = 3.9916e-04
#
#  56% 9/16 [00:00<00:00,  9.43it/s]
#  62% 10/16 [00:01<00:00,  9.49it/s]
#  69% 11/16 [00:01<00:00,  9.46it/s]
#  75% 12/16 [00:01<00:00,  9.10it/s]
#  81% 13/16 [00:01<00:00,  9.15it/s]
#  94% 15/16 [00:01<00:00,  9.34it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 15.22it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.686642
#  40% 24/60 [00:53<01:12,  2.02s/it]Epoch 24
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:01,  8.72it/s]Loss = 6.9154e-02, PNorm = 35.0685, GNorm = 1.3055, lr_0 = 3.8874e-04
#
#  12% 2/16 [00:00<00:01,  8.69it/s]
#  19% 3/16 [00:00<00:01,  9.16it/s]
#  31% 5/16 [00:00<00:01, 10.18it/s]
#  38% 6/16 [00:00<00:01,  9.37it/s]
#  44% 7/16 [00:00<00:00,  9.50it/s]
#  50% 8/16 [00:00<00:00,  9.06it/s]
#  56% 9/16 [00:00<00:00,  8.89it/s]
#  69% 11/16 [00:01<00:00,  9.20it/s]Loss = 7.1634e-02, PNorm = 35.0795, GNorm = 4.0435, lr_0 = 3.7858e-04
#
#  75% 12/16 [00:01<00:00,  8.83it/s]
#  88% 14/16 [00:01<00:00,  8.82it/s]
# 100% 16/16 [00:01<00:00,  9.48it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 15.17it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.716963
#  42% 25/60 [00:55<01:09,  1.98s/it]Epoch 25
#
#   0% 0/16 [00:00<?, ?it/s]
#  12% 2/16 [00:00<00:01,  9.32it/s]
#  19% 3/16 [00:00<00:01,  8.94it/s]
#  25% 4/16 [00:00<00:01,  9.13it/s]
#  31% 5/16 [00:00<00:01,  9.07it/s]Loss = 5.6228e-02, PNorm = 35.0948, GNorm = 1.3388, lr_0 = 3.6869e-04
#
#  38% 6/16 [00:00<00:01,  7.73it/s]
#  44% 7/16 [00:00<00:01,  7.02it/s]
#  50% 8/16 [00:01<00:01,  6.43it/s]
#  56% 9/16 [00:01<00:01,  6.26it/s]
#  62% 10/16 [00:01<00:00,  6.10it/s]
#  69% 11/16 [00:01<00:00,  6.03it/s]
#  75% 12/16 [00:01<00:00,  5.69it/s]
#  81% 13/16 [00:01<00:00,  5.61it/s]
#  88% 14/16 [00:02<00:00,  5.89it/s]
#  94% 15/16 [00:02<00:00,  5.90it/s]Loss = 7.0418e-02, PNorm = 35.1102, GNorm = 1.0366, lr_0 = 3.5906e-04
#
# 100% 16/16 [00:02<00:00,  5.95it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  33% 1/3 [00:00<00:00,  9.68it/s]
#  67% 2/3 [00:00<00:00,  8.93it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.701318
#  43% 26/60 [00:57<01:14,  2.20s/it]Epoch 26
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:02,  6.03it/s]
#  12% 2/16 [00:00<00:02,  5.77it/s]
#  19% 3/16 [00:00<00:02,  6.04it/s]
#  25% 4/16 [00:00<00:02,  5.68it/s]
#  31% 5/16 [00:00<00:02,  5.47it/s]
#  38% 6/16 [00:01<00:01,  5.66it/s]
#  44% 7/16 [00:01<00:01,  5.69it/s]
#  50% 8/16 [00:01<00:01,  5.81it/s]
#  56% 9/16 [00:01<00:01,  6.04it/s]Loss = 6.6408e-02, PNorm = 35.1235, GNorm = 2.0055, lr_0 = 3.4969e-04
#
#  62% 10/16 [00:01<00:01,  5.98it/s]
#  69% 11/16 [00:01<00:00,  5.71it/s]
#  75% 12/16 [00:02<00:00,  5.72it/s]
#  81% 13/16 [00:02<00:00,  6.31it/s]
#  88% 14/16 [00:02<00:00,  7.04it/s]
#  94% 15/16 [00:02<00:00,  7.69it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 15.50it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.733282
#  45% 27/60 [01:00<01:17,  2.33s/it]Epoch 27
#
#   0% 0/16 [00:00<?, ?it/s]
#  12% 2/16 [00:00<00:01,  9.77it/s]
#  19% 3/16 [00:00<00:01,  9.40it/s]Loss = 5.6389e-02, PNorm = 35.1354, GNorm = 2.8499, lr_0 = 3.4055e-04
#
#  31% 5/16 [00:00<00:01,  9.81it/s]
#  38% 6/16 [00:00<00:01,  9.47it/s]
#  44% 7/16 [00:00<00:00,  9.53it/s]
#  50% 8/16 [00:00<00:00,  9.26it/s]
#  56% 9/16 [00:00<00:00,  9.17it/s]
#  62% 10/16 [00:01<00:00,  9.35it/s]
#  69% 11/16 [00:01<00:00,  9.47it/s]
#  75% 12/16 [00:01<00:00,  8.85it/s]
#  81% 13/16 [00:01<00:00,  8.60it/s]Loss = 5.7786e-02, PNorm = 35.1495, GNorm = 2.6454, lr_0 = 3.3166e-04
#
#  88% 14/16 [00:01<00:00,  8.51it/s]
#  94% 15/16 [00:01<00:00,  8.08it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 15.48it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.696854
#  47% 28/60 [01:02<01:10,  2.21s/it]Epoch 28
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:01,  9.29it/s]
#  19% 3/16 [00:00<00:01,  9.82it/s]
#  25% 4/16 [00:00<00:01,  9.67it/s]
#  38% 6/16 [00:00<00:01,  9.81it/s]
#  44% 7/16 [00:00<00:00,  9.66it/s]
#  50% 8/16 [00:00<00:00,  9.45it/s]Loss = 6.0372e-02, PNorm = 35.1631, GNorm = 1.8148, lr_0 = 3.2214e-04
#
#  56% 9/16 [00:00<00:00,  9.16it/s]
#  62% 10/16 [00:01<00:00,  9.20it/s]
#  69% 11/16 [00:01<00:00,  8.99it/s]
#  75% 12/16 [00:01<00:00,  9.14it/s]
#  81% 13/16 [00:01<00:00,  8.60it/s]
#  88% 14/16 [00:01<00:00,  8.94it/s]
#  94% 15/16 [00:01<00:00,  9.05it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 16.78it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.659910
#  48% 29/60 [01:04<01:05,  2.12s/it]Epoch 29
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:01,  8.49it/s]Loss = 4.9644e-02, PNorm = 35.1737, GNorm = 0.5387, lr_0 = 3.1373e-04
#
#  19% 3/16 [00:00<00:01,  9.97it/s]
#  25% 4/16 [00:00<00:01,  9.66it/s]
#  31% 5/16 [00:00<00:01,  9.36it/s]
#  44% 7/16 [00:00<00:00,  9.38it/s]
#  56% 9/16 [00:00<00:00,  9.63it/s]
#  62% 10/16 [00:01<00:00,  9.21it/s]
#  69% 11/16 [00:01<00:00,  9.27it/s]
#  75% 12/16 [00:01<00:00,  9.32it/s]Loss = 4.5947e-02, PNorm = 35.1844, GNorm = 1.0243, lr_0 = 3.0553e-04
#
#  81% 13/16 [00:01<00:00,  9.04it/s]
#  88% 14/16 [00:01<00:00,  8.96it/s]
#  94% 15/16 [00:01<00:00,  8.68it/s]
# 100% 16/16 [00:01<00:00,  8.86it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 16.14it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.642688
#  50% 30/60 [01:06<01:02,  2.07s/it]Epoch 30
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:01,  9.32it/s]
#  19% 3/16 [00:00<00:01,  9.91it/s]
#  25% 4/16 [00:00<00:01,  9.62it/s]
#  31% 5/16 [00:00<00:01,  9.32it/s]
#  38% 6/16 [00:00<00:01,  9.17it/s]Loss = 5.5016e-02, PNorm = 35.1929, GNorm = 0.9794, lr_0 = 2.9755e-04
#
#  44% 7/16 [00:00<00:01,  8.57it/s]
#  50% 8/16 [00:00<00:00,  8.50it/s]
#  56% 9/16 [00:01<00:00,  8.74it/s]
#  62% 10/16 [00:01<00:00,  8.95it/s]
#  69% 11/16 [00:01<00:00,  8.42it/s]
#  81% 13/16 [00:01<00:00,  9.10it/s]
#  88% 14/16 [00:01<00:00,  9.18it/s]
#  94% 15/16 [00:01<00:00,  9.14it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 16.27it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.640255
#  52% 31/60 [01:08<00:59,  2.04s/it]Epoch 31
#
#   0% 0/16 [00:00<?, ?it/s]Loss = 3.7205e-02, PNorm = 35.2030, GNorm = 1.9968, lr_0 = 2.8978e-04
#
#  12% 2/16 [00:00<00:01, 10.37it/s]
#  25% 4/16 [00:00<00:01,  9.22it/s]
#  38% 6/16 [00:00<00:01,  9.30it/s]
#  44% 7/16 [00:00<00:00,  9.11it/s]
#  50% 8/16 [00:00<00:00,  9.18it/s]
#  56% 9/16 [00:00<00:00,  9.06it/s]Loss = 4.4576e-02, PNorm = 35.2115, GNorm = 3.7779, lr_0 = 2.8221e-04
#
#  69% 11/16 [00:01<00:00,  9.35it/s]
#  75% 12/16 [00:01<00:00,  9.05it/s]
#  81% 13/16 [00:01<00:00,  8.93it/s]
#  88% 14/16 [00:01<00:00,  9.10it/s]
#  94% 15/16 [00:01<00:00,  8.86it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00,  9.37it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.681119
#  53% 32/60 [01:10<00:56,  2.03s/it]Epoch 32
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:02,  6.51it/s]
#  12% 2/16 [00:00<00:02,  5.86it/s]
#  19% 3/16 [00:00<00:02,  6.07it/s]
#  25% 4/16 [00:00<00:02,  5.58it/s]
#  31% 5/16 [00:00<00:02,  5.02it/s]Loss = 4.3398e-02, PNorm = 35.2223, GNorm = 1.4342, lr_0 = 2.7411e-04
#
#  38% 6/16 [00:01<00:01,  5.31it/s]
#  44% 7/16 [00:01<00:01,  5.19it/s]
#  50% 8/16 [00:01<00:01,  5.27it/s]
#  56% 9/16 [00:01<00:01,  5.43it/s]
#  62% 10/16 [00:01<00:01,  5.53it/s]
#  69% 11/16 [00:02<00:00,  5.30it/s]
#  75% 12/16 [00:02<00:00,  5.32it/s]
#  81% 13/16 [00:02<00:00,  5.46it/s]
#  88% 14/16 [00:02<00:00,  5.56it/s]
#  94% 15/16 [00:02<00:00,  5.63it/s]Loss = 4.5207e-02, PNorm = 35.2342, GNorm = 0.7506, lr_0 = 2.6695e-04
#
# 100% 16/16 [00:02<00:00,  6.18it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  33% 1/3 [00:00<00:00,  8.51it/s]
#  67% 2/3 [00:00<00:00,  7.93it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.691431
#  55% 33/60 [01:13<01:03,  2.36s/it]Epoch 33
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:02,  5.07it/s]
#  12% 2/16 [00:00<00:02,  5.93it/s]
#  19% 3/16 [00:00<00:02,  5.68it/s]
#  25% 4/16 [00:00<00:02,  5.64it/s]
#  31% 5/16 [00:00<00:01,  6.33it/s]
#  38% 6/16 [00:00<00:01,  6.60it/s]
#  44% 7/16 [00:01<00:01,  7.41it/s]
#  50% 8/16 [00:01<00:01,  7.92it/s]
#  56% 9/16 [00:01<00:00,  7.84it/s]Loss = 4.5535e-02, PNorm = 35.2423, GNorm = 0.6218, lr_0 = 2.5998e-04
#
#  69% 11/16 [00:01<00:00,  8.76it/s]
#  75% 12/16 [00:01<00:00,  8.94it/s]
#  81% 13/16 [00:01<00:00,  9.06it/s]
#  88% 14/16 [00:01<00:00,  9.13it/s]
#  94% 15/16 [00:01<00:00,  9.16it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 14.78it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.691785
#  57% 34/60 [01:15<01:00,  2.31s/it]Epoch 34
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:01,  9.00it/s]
#  12% 2/16 [00:00<00:01,  8.83it/s]
#  19% 3/16 [00:00<00:01,  8.81it/s]Loss = 4.7885e-02, PNorm = 35.2519, GNorm = 3.2317, lr_0 = 2.5319e-04
#
#  25% 4/16 [00:00<00:02,  4.98it/s]
#  31% 5/16 [00:00<00:01,  5.89it/s]
#  38% 6/16 [00:00<00:01,  6.76it/s]
#  50% 8/16 [00:01<00:00,  8.14it/s]
#  56% 9/16 [00:01<00:00,  8.50it/s]
#  62% 10/16 [00:01<00:00,  8.33it/s]
#  69% 11/16 [00:01<00:00,  8.45it/s]
#  75% 12/16 [00:01<00:00,  8.60it/s]
#  81% 13/16 [00:01<00:00,  8.48it/s]Loss = 4.5721e-02, PNorm = 35.2616, GNorm = 1.6360, lr_0 = 2.4658e-04
#
#  88% 14/16 [00:01<00:00,  8.81it/s]
#  94% 15/16 [00:01<00:00,  8.27it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 16.54it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.666340
#  58% 35/60 [01:17<00:56,  2.26s/it]Epoch 35
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:01,  8.40it/s]
#  19% 3/16 [00:00<00:01,  9.37it/s]
#  25% 4/16 [00:00<00:01,  8.84it/s]
#  31% 5/16 [00:00<00:01,  8.90it/s]
#  38% 6/16 [00:00<00:01,  8.83it/s]
#  44% 7/16 [00:00<00:01,  8.48it/s]Loss = 4.7794e-02, PNorm = 35.2702, GNorm = 1.2232, lr_0 = 2.4014e-04
#
#  50% 8/16 [00:00<00:00,  8.60it/s]
#  56% 9/16 [00:01<00:00,  8.31it/s]
#  62% 10/16 [00:01<00:00,  8.58it/s]
#  69% 11/16 [00:01<00:00,  8.68it/s]
#  75% 12/16 [00:01<00:00,  8.74it/s]
#  88% 14/16 [00:01<00:00,  9.72it/s]
#  94% 15/16 [00:01<00:00,  9.41it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 16.55it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.660359
#  60% 36/60 [01:19<00:51,  2.15s/it]Epoch 36
#
#   0% 0/16 [00:00<?, ?it/s]Loss = 4.6400e-02, PNorm = 35.2790, GNorm = 0.9460, lr_0 = 2.3387e-04
#
#  12% 2/16 [00:00<00:01,  9.26it/s]
#  25% 4/16 [00:00<00:01,  9.64it/s]
#  31% 5/16 [00:00<00:01,  9.36it/s]
#  44% 7/16 [00:00<00:00,  9.54it/s]
#  50% 8/16 [00:00<00:00,  9.61it/s]
#  56% 9/16 [00:00<00:00,  9.17it/s]
#  69% 11/16 [00:01<00:00,  9.14it/s]Loss = 4.3595e-02, PNorm = 35.2867, GNorm = 0.8509, lr_0 = 2.2776e-04
#
#  81% 13/16 [00:01<00:00,  9.23it/s]
#  88% 14/16 [00:01<00:00,  9.07it/s]
#  94% 15/16 [00:01<00:00,  9.16it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 14.95it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.723651
#  62% 37/60 [01:21<00:47,  2.07s/it]Epoch 37
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:01,  7.94it/s]
#  12% 2/16 [00:00<00:01,  8.30it/s]
#  19% 3/16 [00:00<00:01,  8.48it/s]
#  25% 4/16 [00:00<00:01,  8.99it/s]
#  31% 5/16 [00:00<00:01,  8.54it/s]Loss = 4.5817e-02, PNorm = 35.2963, GNorm = 1.3890, lr_0 = 2.2122e-04
#
#  44% 7/16 [00:00<00:01,  8.86it/s]
#  50% 8/16 [00:00<00:00,  8.67it/s]
#  56% 9/16 [00:01<00:00,  8.57it/s]
#  62% 10/16 [00:01<00:00,  8.70it/s]
#  75% 12/16 [00:01<00:00,  9.51it/s]
#  81% 13/16 [00:01<00:00,  9.23it/s]
#  88% 14/16 [00:01<00:00,  9.03it/s]
#  94% 15/16 [00:01<00:00,  9.17it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 15.10it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.658853
#  63% 38/60 [01:23<00:44,  2.02s/it]Epoch 38
#
#   0% 0/16 [00:00<?, ?it/s]Loss = 4.4626e-02, PNorm = 35.3036, GNorm = 1.5591, lr_0 = 2.1544e-04
#
#   6% 1/16 [00:00<00:01,  9.69it/s]
#  12% 2/16 [00:00<00:01,  8.45it/s]
#  25% 4/16 [00:00<00:01,  9.68it/s]
#  31% 5/16 [00:00<00:01,  9.22it/s]
#  38% 6/16 [00:00<00:01,  8.66it/s]
#  44% 7/16 [00:00<00:01,  8.60it/s]
#  50% 8/16 [00:00<00:01,  7.31it/s]
#  56% 9/16 [00:01<00:01,  6.75it/s]
#  62% 10/16 [00:01<00:00,  6.23it/s]Loss = 3.8654e-02, PNorm = 35.3106, GNorm = 1.3497, lr_0 = 2.0982e-04
#
#  69% 11/16 [00:01<00:00,  5.77it/s]
#  75% 12/16 [00:01<00:00,  5.70it/s]
#  81% 13/16 [00:01<00:00,  5.85it/s]
#  88% 14/16 [00:02<00:00,  5.92it/s]
#  94% 15/16 [00:02<00:00,  5.83it/s]
# 100% 16/16 [00:02<00:00,  6.20it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  33% 1/3 [00:00<00:00,  8.95it/s]
#  67% 2/3 [00:00<00:00,  8.82it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.700926
#  65% 39/60 [01:26<00:46,  2.20s/it]Epoch 39
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:02,  6.13it/s]
#  12% 2/16 [00:00<00:02,  6.20it/s]
#  19% 3/16 [00:00<00:02,  6.22it/s]
#  25% 4/16 [00:00<00:01,  6.05it/s]Loss = 4.6494e-02, PNorm = 35.3170, GNorm = 1.0638, lr_0 = 2.0434e-04
#
#  31% 5/16 [00:00<00:01,  5.63it/s]
#  38% 6/16 [00:01<00:01,  5.83it/s]
#  44% 7/16 [00:01<00:01,  5.64it/s]
#  50% 8/16 [00:01<00:01,  5.78it/s]
#  56% 9/16 [00:01<00:01,  5.46it/s]
#  62% 10/16 [00:01<00:01,  5.63it/s]
#  69% 11/16 [00:01<00:00,  5.57it/s]
#  75% 12/16 [00:02<00:00,  5.50it/s]
#  81% 13/16 [00:02<00:00,  5.44it/s]
#  88% 14/16 [00:02<00:00,  5.89it/s]Loss = 3.8890e-02, PNorm = 35.3251, GNorm = 0.7180, lr_0 = 1.9900e-04
#
#  94% 15/16 [00:02<00:00,  6.67it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 16.56it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.669086
#  67% 40/60 [01:28<00:47,  2.37s/it]Epoch 40
#
# ...
#
#  56% 9/16 [00:00<00:00,  9.37it/s]
#  62% 10/16 [00:01<00:00,  9.11it/s]
#  69% 11/16 [00:01<00:00,  8.74it/s]
#  75% 12/16 [00:01<00:00,  8.76it/s]
#  81% 13/16 [00:01<00:00,  9.01it/s]
#  94% 15/16 [00:01<00:00,  9.31it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 15.76it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.653759
#  80% 48/60 [01:46<00:26,  2.20s/it]Epoch 48
#
#   0% 0/16 [00:00<?, ?it/s]
#  12% 2/16 [00:00<00:01,  8.75it/s]Loss = 3.4087e-02, PNorm = 35.4031, GNorm = 0.5571, lr_0 = 1.4032e-04
#
#  19% 3/16 [00:00<00:01,  8.61it/s]
#  25% 4/16 [00:00<00:01,  8.36it/s]
#  31% 5/16 [00:00<00:01,  8.29it/s]
#  38% 6/16 [00:00<00:01,  8.77it/s]
#  44% 7/16 [00:00<00:00,  9.00it/s]
#  50% 8/16 [00:00<00:00,  8.53it/s]
#  62% 10/16 [00:01<00:00,  8.93it/s]
#  69% 11/16 [00:01<00:00,  8.92it/s]Loss = 3.6747e-02, PNorm = 35.4094, GNorm = 0.8521, lr_0 = 1.3666e-04
#
#  81% 13/16 [00:01<00:00,  9.49it/s]
#  88% 14/16 [00:01<00:00,  9.06it/s]
# 100% 16/16 [00:01<00:00, 10.01it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 14.82it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.662504
#  82% 49/60 [01:48<00:23,  2.11s/it]Epoch 49
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:01,  8.83it/s]
#  12% 2/16 [00:00<00:01,  8.25it/s]
#  25% 4/16 [00:00<00:01,  9.14it/s]
#  31% 5/16 [00:00<00:01,  9.10it/s]
#  38% 6/16 [00:00<00:01,  8.97it/s]Loss = 3.3275e-02, PNorm = 35.4130, GNorm = 1.8470, lr_0 = 1.3309e-04
#
#  44% 7/16 [00:00<00:00,  9.14it/s]
#  50% 8/16 [00:00<00:00,  9.23it/s]
#  56% 9/16 [00:00<00:00,  9.22it/s]
#  62% 10/16 [00:01<00:00,  9.36it/s]
#  69% 11/16 [00:01<00:00,  9.48it/s]
#  75% 12/16 [00:01<00:00,  8.97it/s]
#  81% 13/16 [00:01<00:00,  9.04it/s]
#  88% 14/16 [00:01<00:00,  9.01it/s]
#  94% 15/16 [00:01<00:00,  8.56it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 16.06it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.653854
#  83% 50/60 [01:50<00:20,  2.05s/it]Epoch 50
#
#   0% 0/16 [00:00<?, ?it/s]Loss = 2.8459e-02, PNorm = 35.4173, GNorm = 2.0577, lr_0 = 1.2961e-04
#
#   6% 1/16 [00:00<00:01,  7.96it/s]
#  12% 2/16 [00:00<00:01,  7.81it/s]
#  19% 3/16 [00:00<00:01,  8.57it/s]
#  25% 4/16 [00:00<00:01,  8.89it/s]
#  31% 5/16 [00:00<00:01,  9.07it/s]
#  44% 7/16 [00:00<00:00,  9.16it/s]
#  50% 8/16 [00:00<00:00,  9.19it/s]
#  56% 9/16 [00:01<00:00,  8.76it/s]
#  62% 10/16 [00:01<00:00,  8.77it/s]Loss = 3.4843e-02, PNorm = 35.4218, GNorm = 0.4529, lr_0 = 1.2623e-04
#
#  75% 12/16 [00:01<00:00,  9.09it/s]
#  81% 13/16 [00:01<00:00,  9.00it/s]
#  88% 14/16 [00:01<00:00,  9.16it/s]
#  94% 15/16 [00:01<00:00,  9.36it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 14.15it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.648320
#  85% 51/60 [01:51<00:18,  2.01s/it]Epoch 51
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:01,  9.34it/s]
#  12% 2/16 [00:00<00:01,  9.54it/s]
#  19% 3/16 [00:00<00:01,  9.50it/s]
#  25% 4/16 [00:00<00:01,  9.05it/s]
#  31% 5/16 [00:00<00:01,  9.26it/s]Loss = 3.2193e-02, PNorm = 35.4266, GNorm = 0.6910, lr_0 = 1.2260e-04
#
#  38% 6/16 [00:00<00:01,  9.01it/s]
#  44% 7/16 [00:00<00:00,  9.04it/s]
#  56% 9/16 [00:01<00:00,  8.20it/s]
#  62% 10/16 [00:01<00:00,  7.46it/s]
#  69% 11/16 [00:01<00:00,  6.71it/s]
#  75% 12/16 [00:01<00:00,  6.57it/s]
#  81% 13/16 [00:01<00:00,  6.08it/s]
#  88% 14/16 [00:01<00:00,  6.21it/s]
#  94% 15/16 [00:02<00:00,  5.86it/s]Loss = 3.6656e-02, PNorm = 35.4310, GNorm = 1.7329, lr_0 = 1.1940e-04
#
# 100% 16/16 [00:02<00:00,  5.89it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  33% 1/3 [00:00<00:00,  8.41it/s]
#  67% 2/3 [00:00<00:00,  8.68it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.642606
#  87% 52/60 [01:54<00:17,  2.17s/it]Epoch 52
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:02,  5.60it/s]
#  12% 2/16 [00:00<00:02,  6.07it/s]
#  19% 3/16 [00:00<00:02,  5.50it/s]
#  25% 4/16 [00:00<00:02,  5.19it/s]
#  31% 5/16 [00:00<00:02,  5.34it/s]
#  38% 6/16 [00:01<00:01,  5.23it/s]
#  44% 7/16 [00:01<00:01,  5.43it/s]
#  50% 8/16 [00:01<00:01,  5.64it/s]
#  56% 9/16 [00:01<00:01,  5.82it/s]Loss = 2.8736e-02, PNorm = 35.4350, GNorm = 0.3979, lr_0 = 1.1628e-04
#
#  62% 10/16 [00:01<00:01,  5.59it/s]
#  69% 11/16 [00:01<00:00,  5.60it/s]
#  75% 12/16 [00:02<00:00,  5.75it/s]
#  81% 13/16 [00:02<00:00,  5.78it/s]
#  88% 14/16 [00:02<00:00,  6.15it/s]
#  94% 15/16 [00:02<00:00,  6.75it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 15.33it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.643405
#  88% 53/60 [01:57<00:16,  2.36s/it]Epoch 53
#
#   0% 0/16 [00:00<?, ?it/s]
#  12% 2/16 [00:00<00:01,  9.43it/s]
#  19% 3/16 [00:00<00:01,  8.96it/s]Loss = 3.6835e-02, PNorm = 35.4399, GNorm = 2.2385, lr_0 = 1.1325e-04
#
#  31% 5/16 [00:00<00:01,  9.44it/s]
#  38% 6/16 [00:00<00:01,  9.41it/s]
#  44% 7/16 [00:00<00:00,  9.37it/s]
#  50% 8/16 [00:00<00:00,  9.39it/s]
#  56% 9/16 [00:00<00:00,  9.01it/s]
#  69% 11/16 [00:01<00:00,  9.68it/s]
#  75% 12/16 [00:01<00:00,  8.97it/s]Loss = 3.1516e-02, PNorm = 35.4436, GNorm = 0.5736, lr_0 = 1.1029e-04
#
#  88% 14/16 [00:01<00:00,  9.23it/s]
#  94% 15/16 [00:01<00:00,  8.97it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 15.70it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.641908
#  90% 54/60 [01:59<00:13,  2.22s/it]Epoch 54
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:01,  7.97it/s]
#  12% 2/16 [00:00<00:01,  8.97it/s]
#  19% 3/16 [00:00<00:01,  9.14it/s]
#  25% 4/16 [00:00<00:01,  8.51it/s]
#  38% 6/16 [00:00<00:01,  9.18it/s]
#  44% 7/16 [00:00<00:00,  9.30it/s]Loss = 3.5642e-02, PNorm = 35.4470, GNorm = 0.5495, lr_0 = 1.0741e-04
#
#  50% 8/16 [00:00<00:00,  9.43it/s]
#  56% 9/16 [00:00<00:00,  9.38it/s]
#  62% 10/16 [00:01<00:00,  9.17it/s]
#  75% 12/16 [00:01<00:00,  9.56it/s]
#  81% 13/16 [00:01<00:00,  9.49it/s]
#  88% 14/16 [00:01<00:00,  9.15it/s]
# 100% 16/16 [00:01<00:00,  9.74it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 16.94it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.644893
#  92% 55/60 [02:01<00:10,  2.11s/it]Epoch 55
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:01,  8.98it/s]
#  12% 2/16 [00:00<00:01,  9.34it/s]Loss = 3.7577e-02, PNorm = 35.4510, GNorm = 1.0221, lr_0 = 1.0433e-04
#
#  19% 3/16 [00:00<00:01,  8.84it/s]
#  25% 4/16 [00:00<00:01,  8.65it/s]
#  31% 5/16 [00:00<00:01,  9.02it/s]
#  38% 6/16 [00:00<00:01,  9.27it/s]
#  44% 7/16 [00:00<00:00,  9.36it/s]
#  50% 8/16 [00:00<00:00,  9.14it/s]
#  56% 9/16 [00:01<00:00,  8.73it/s]
#  62% 10/16 [00:01<00:00,  8.41it/s]
#  69% 11/16 [00:01<00:00,  8.60it/s]
#  75% 12/16 [00:01<00:00,  8.03it/s]Loss = 3.3623e-02, PNorm = 35.4548, GNorm = 1.1563, lr_0 = 1.0160e-04
#
#  81% 13/16 [00:01<00:00,  8.41it/s]
#  88% 14/16 [00:01<00:00,  8.79it/s]
#  94% 15/16 [00:01<00:00,  8.56it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 16.81it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.648207
#  93% 56/60 [02:02<00:08,  2.06s/it]Epoch 56
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:01,  9.18it/s]
#  12% 2/16 [00:00<00:01,  8.99it/s]
#  25% 4/16 [00:00<00:01,  9.00it/s]
#  38% 6/16 [00:00<00:01,  9.60it/s]Loss = 3.9042e-02, PNorm = 35.4588, GNorm = 1.0005, lr_0 = 1.0000e-04
#
#  44% 7/16 [00:00<00:00,  9.06it/s]
#  56% 9/16 [00:00<00:00,  9.20it/s]
#  62% 10/16 [00:01<00:00,  9.13it/s]
#  69% 11/16 [00:01<00:00,  9.18it/s]
#  81% 13/16 [00:01<00:00,  9.27it/s]
#  88% 14/16 [00:01<00:00,  9.36it/s]
#  94% 15/16 [00:01<00:00,  9.30it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 16.95it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.645460
#  95% 57/60 [02:04<00:06,  2.00s/it]Epoch 57
#
#   0% 0/16 [00:00<?, ?it/s]Loss = 2.6411e-02, PNorm = 35.4623, GNorm = 0.9160, lr_0 = 1.0000e-04
#
#   6% 1/16 [00:00<00:01,  9.25it/s]
#  12% 2/16 [00:00<00:01,  9.17it/s]
#  19% 3/16 [00:00<00:01,  9.35it/s]
#  25% 4/16 [00:00<00:01,  8.96it/s]
#  31% 5/16 [00:00<00:01,  8.80it/s]
#  38% 6/16 [00:00<00:01,  8.49it/s]
#  44% 7/16 [00:00<00:01,  8.79it/s]
#  50% 8/16 [00:00<00:00,  8.91it/s]
#  62% 10/16 [00:01<00:00,  8.97it/s]Loss = 2.7888e-02, PNorm = 35.4660, GNorm = 0.9462, lr_0 = 1.0000e-04
#
#  69% 11/16 [00:01<00:00,  8.99it/s]
#  75% 12/16 [00:01<00:00,  8.76it/s]
#  81% 13/16 [00:01<00:00,  9.05it/s]
#  94% 15/16 [00:01<00:00,  8.87it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 16.50it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.647944
#  97% 58/60 [02:06<00:03,  1.97s/it]Epoch 58
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:01,  8.02it/s]
#  12% 2/16 [00:00<00:02,  6.74it/s]
#  19% 3/16 [00:00<00:02,  6.32it/s]
#  25% 4/16 [00:00<00:01,  6.18it/s]Loss = 2.7913e-02, PNorm = 35.4688, GNorm = 0.5015, lr_0 = 1.0000e-04
#
#  31% 5/16 [00:00<00:01,  5.75it/s]
#  38% 6/16 [00:00<00:01,  5.81it/s]
#  44% 7/16 [00:01<00:01,  5.93it/s]
#  50% 8/16 [00:01<00:01,  5.84it/s]
#  56% 9/16 [00:01<00:01,  5.50it/s]
#  62% 10/16 [00:01<00:01,  5.56it/s]
#  69% 11/16 [00:01<00:00,  5.37it/s]
#  75% 12/16 [00:02<00:00,  5.55it/s]
#  81% 13/16 [00:02<00:00,  5.67it/s]
#  88% 14/16 [00:02<00:00,  5.62it/s]Loss = 3.0733e-02, PNorm = 35.4727, GNorm = 0.8268, lr_0 = 1.0000e-04
#
#  94% 15/16 [00:02<00:00,  5.56it/s]
# 100% 16/16 [00:02<00:00,  6.08it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  33% 1/3 [00:00<00:00,  9.29it/s]
#  67% 2/3 [00:00<00:00,  7.80it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.636957
#  98% 59/60 [02:09<00:02,  2.33s/it]Epoch 59
#
#   0% 0/16 [00:00<?, ?it/s]
#   6% 1/16 [00:00<00:02,  6.67it/s]
#  12% 2/16 [00:00<00:02,  5.96it/s]
#  19% 3/16 [00:00<00:02,  6.19it/s]
#  25% 4/16 [00:00<00:02,  5.71it/s]
#  31% 5/16 [00:00<00:01,  5.76it/s]
#  38% 6/16 [00:01<00:01,  5.62it/s]
#  44% 7/16 [00:01<00:01,  5.96it/s]
#  50% 8/16 [00:01<00:01,  5.70it/s]Loss = 3.2488e-02, PNorm = 35.4762, GNorm = 1.3030, lr_0 = 1.0000e-04
#
#  56% 9/16 [00:01<00:01,  5.58it/s]
#  62% 10/16 [00:01<00:01,  5.67it/s]
#  69% 11/16 [00:01<00:00,  6.49it/s]
#  75% 12/16 [00:01<00:00,  7.23it/s]
#  81% 13/16 [00:02<00:00,  7.22it/s]
#  88% 14/16 [00:02<00:00,  7.88it/s]
#  94% 15/16 [00:02<00:00,  8.26it/s]
#
#   0% 0/3 [00:00<?, ?it/s]
#  67% 2/3 [00:00<00:00, 17.28it/s]
#                                  /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Validation rmse = 0.640032
# 100% 60/60 [02:12<00:00,  2.21s/it]
# Model 0 best validation rmse = 0.636957 on epoch 58
# /usr/local/lib/python3.10/dist-packages/chemprop/utils.py:112: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(path, map_location=lambda storage, loc: storage)
# Loading pretrained parameter "encoder.encoder.0.cached_zero_vector".
# Loading pretrained parameter "encoder.encoder.0.W_i.weight".
# Loading pretrained parameter "encoder.encoder.0.W_h.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.weight".
# Loading pretrained parameter "encoder.encoder.0.W_o.bias".
# Loading pretrained parameter "readout.1.weight".
# Loading pretrained parameter "readout.1.bias".
# Loading pretrained parameter "readout.4.weight".
# Loading pretrained parameter "readout.4.bias".
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Model 0 test rmse = 0.648955
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Ensemble test rmse = 0.648955
# 1-fold cross validation
# 	Seed 0 ==> test rmse = 0.648955
# Overall test rmse = 0.648955 +/- 0.000000
# Elapsed time = 0:02:19
